# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkKryvoshein/MachineLearning/blob/main/UnsupervisedLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
np.random.seed(42)
X = np.vstack((np.random.randn(50, 2) + [2, 2], np.random.randn(50, 2) + [7, 7]))

# %%
plt.scatter(X[:, 0], X[:, 1], s=50, color="grey")
plt.show()

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# %%
plt.scatter(X[:, 0],
            X[:, 1],
            s=50,
            c=labels,
            cmap='viridis'
            )
plt.scatter(centers[:, 0],
            centers[:, 1],
            c = "red",
            s=200,
            marker='x',
            label="Точка центроїди"
            )
plt.legend()
plt.show()
